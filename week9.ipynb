# %% [markdown]
# # Week 9

# %% [markdown]
# ![w9b.jpg](attachment:w9b.jpg)

# %% [raw]
# c = 0
# def add(x):
#         tot = int(x) + int(x[::-1])
#         global c
#         c += 1
#         tot = str(tot)
#         if tot != tot[::-1]:
#                 add(tot)
#         else:
#                 print(c , tot)
#                 c = 0
#
# def main():
#         loop = int(input())
#         for i in range(loop):
#                 x = input()
#                 add(x)
# __name__ = main()

# %% [markdown]
# ![w9a.jpg](attachment:w9a.jpg)

# %% [raw]
# def plus(i, j, arr):
#         if -1 < i < x and -1 < j < y:
#                 if arr[i][j] != '*':
#                         arr[i][j] += 1
#         return arr
#
#
# def main():
#         a = input().split()
#         global x
#         global y
#         c = 1
#         x = int(a[0])
#         y = int(a[1])
#         while x != 0 and y != 0:
#                 arr = [[0 for i in range(y)] for i in range(x)]
#                 for i in range(x):
#                         txt = input().split()
#                         for j in range(y):
#                                 if txt[j] == "*":
#                                         arr = plus(i - 1, j - 1, arr)
#                                         arr = plus(i - 1, j, arr)
#                                         arr = plus(i - 1, j + 1, arr)
#                                         arr = plus(i, j - 1, arr)
#                                         arr[i][j] = '*'
#                                         arr = plus(i, j + 1, arr)
#                                         arr = plus(i + 1, j - 1, arr)
#                                         arr = plus(i + 1, j, arr)
#                                         arr = plus(i + 1, j + 1, arr)
#                 print(f"Field #{c}:")
#                 for i in range(x):
#                         for j in range(y):
#                                 print(arr[i][j], end=" ")
#                         print()
#                 c += 1
#                 a = input().split()
#                 x = int(a[0])
#                 y = int(a[1])
# __name__==main()

# %% [markdown]
# # Week 10

# %% [markdown]
# ![w10b.jpg](attachment:w10b.jpg)

# %% [raw]
# def changeColor(n, m, org, k):
#             if -1 < n < x and -1 < m < y and arr[n][m] == org:
#                         arr[n][m] = k
#                         changeColor(n - 1, m, org, k)
#                         changeColor(n, m - 1, org, k)
#                         changeColor(n, m + 1, org, k)
#                         changeColor(n + 1, m, org, k)
#             return arr
#
#
# def main():
#             loop = int(input())
#             for lop in range(loop):
#                         size = input().split()
#                         global x
#                         global y
#                         global arr
#                         x = int(size[0])
#                         y = int(size[1])
#                         arr = [[0 for i in range(y)] for i in range(x)]
#                         mat = input().split()
#                         for i in range(len(mat)):
#                                     arr[i//y][i%y] = mat[i]
#                         change = input().split()
#                         cx = int(change[0])
#                         cy = int(change[1])
#                         k = change[2]
#                         org = arr[cx][cy]
#                         arr = changeColor(cx, cy, org, k)
#                         for i in range(x):
#                                     for j in range(y):
#                                                 print(arr[i][j], end = " ")
#                         print()
# __name__==main()

# %% [markdown]
# ![w10a.jpg](attachment:w10a.jpg)

# %% [raw]
# def endIndex(s, f):
#             i =  max(s[::-1].find(f), 0)
#             return len(s) - i - 1
#
# def win(bi, c):
#             i1 = max(bi.find('1'), 0)
#             i0 = endIndex(bi, '0')
#             if i1 < i0:
#                         bi = list(bi)
#                         bi[i1] = '0'
#                         bi[i0] = '1'
#                         bi = "".join(bi)
#                         return win(bi, c + 1)
#             return c
#
# def main():
#             loop = int(input())
#             for i in range(loop):
#                         no = int(input())
#                         res = win(bin(no)[2:], 1)
#                         print(res % 2 +1)
# __name__== main()
